# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/crime_info_sample_of_10.csv')
df2 = pd.read_csv('../data/kc_house_data.csv')
df=df.rename(columns = {'house id':'id'})
df
# Out:
#    Unnamed: 0          id  number of crimes  Assault  Breaking & Entering  \
# 0           0  7129300520               408     32.0                131.0
# 1           1  6414100192                15      1.0                  2.0
# 2           2  5631500400               121     10.0                 20.0
# 3           3  2487200875                 2      0.0                  0.0
# 4           4  1954400510                 0      0.0                  0.0
# 5           5  7237550310                74      4.0                 21.0
# 6           6  1321400060                 3      0.0                  0.0
# 7           7  2008000270                 2      0.0                  0.0
# 8           8  2414600126              4738    435.0                739.0
# 9           9  3793500160                54      5.0                 20.0
#
#    Drugs  Property Crime  Robbery  Theft  Theft from Vehicle  Theft of Vehicle
# ...

# %%
df['id']
# Out:
# 0    7129300520
# 1    6414100192
# 2    5631500400
# 3    2487200875
# 4    1954400510
# 5    7237550310
# 6    1321400060
# 7    2008000270
# 8    2414600126
# 9    3793500160
# Name: id, dtype: int64

# %%
x = pd.merge(df, df2, on='id', how='inner')
x.price.astype(int)
x
# Out:
#    Unnamed: 0          id  number of crimes  Assault  Breaking & Entering  \
# 0           0  7129300520               408     32.0                131.0
# 1           1  6414100192                15      1.0                  2.0
# 2           2  5631500400               121     10.0                 20.0
# 3           3  2487200875                 2      0.0                  0.0
# 4           4  1954400510                 0      0.0                  0.0
# 5           5  7237550310                74      4.0                 21.0
# 6           6  1321400060                 3      0.0                  0.0
# 7           7  2008000270                 2      0.0                  0.0
# 8           8  2414600126              4738    435.0                739.0
# 9           9  3793500160                54      5.0                 20.0
#
#    Drugs  Property Crime  Robbery  Theft  Theft from Vehicle     ...      \
# 0   11.0            85.0      6.0   39.0                54.0     ...
# ...

# %%
x.groupby(['price'])['number of crimes'].mean().plot()

# %%
x.to_csv('../data/merged_data_sample.csv')
