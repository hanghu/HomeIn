# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/house_crime_data.csv')

# %%
df
# Out:
#        Unnamed: 0          id             date      price  bedrooms  \
# 0               0  7129300520  20141013T000000   221900.0         3
# 1               1  6414100192  20141209T000000   538000.0         3
# 2               2  5631500400  20150225T000000   180000.0         2
# 3               3  2487200875  20141209T000000   604000.0         4
# 4               4  1954400510  20150218T000000   510000.0         3
# 5               5  7237550310  20140512T000000  1225000.0         4
# 6               6  1321400060  20140627T000000   257500.0         3
# 7               7  2008000270  20150115T000000   291850.0         3
# 8               8  2414600126  20150415T000000   229500.0         3
# 9               9  3793500160  20150312T000000   323000.0         3
# 10             10  1736800520  20150403T000000   662500.0         3
# 11             11  9212900260  20140527T000000   468000.0         2
# 12             12   114101516  20140528T000000   310000.0         3
# ...

# %%
plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(12, 6))
df.groupby(['price'])['number of crimes'].mean().plot()
