# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/crime_info_sample.csv')
df2 = pd.read_csv('../data/kc_house_data.csv')
df=df.rename(columns = {'house id':'id'})
df
# Out:
#      Unnamed: 0          id  number of crimes  Assault  Breaking & Entering  \
# 0             0  7129300520               408     32.0                131.0
# 1             1  6414100192                15      1.0                  2.0
# 2             2  5631500400               121     10.0                 20.0
# 3             3  2487200875                 2      NaN                  NaN
# 4             4  1954400510                 0      NaN                  NaN
# 5             5  7237550310                74      4.0                 21.0
# 6             6  1321400060                 3      NaN                  NaN
# 7             7  2008000270                 2      NaN                  NaN
# 8             8  2414600126              4738    435.0                739.0
# 9             9  3793500160                54      5.0                 20.0
# 10           10  1736800520                 1      NaN                  NaN
# ...

# %%
df['id']
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
x = pd.merge(df, df2, on='id', how='inner')
x.price.astype(int)
x
# Out:
#       Unnamed: 0          id  number of crimes  Assault  Breaking & Entering  \
# 0              0  7129300520               408     32.0                131.0
# 1              1  6414100192                15      1.0                  2.0
# 2              2  5631500400               121     10.0                 20.0
# 3              3  2487200875                 2      NaN                  NaN
# 4              4  1954400510                 0      NaN                  NaN
# 5              5  7237550310                74      4.0                 21.0
# 6              6  1321400060                 3      NaN                  NaN
# 7              7  2008000270                 2      NaN                  NaN
# 8              8  2414600126              4738    435.0                739.0
# 9              9  3793500160                54      5.0                 20.0
# 10            10  1736800520                 1      NaN                  NaN
# ...

# %%
x.groupby(['price'])['number of crimes'].mean().plot()
