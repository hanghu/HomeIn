# %%
import io
from PIL import Image
import requests

# %%
url = 'https://maps.googleapis.com/maps/api/streetview?size=600x600&location=47.5006259,-122.2340388&pitch=10&key=AIzaSyALN4DKjGjGkg_KA7XFvLSCBlBOMATQdxE'
file = io.BytesIO(urllib.request.urlopen(url).read())
img = Image.open(file)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600 at 0x106C27898>
