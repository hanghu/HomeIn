# %%
import folium

# %%
folium.__version__
# Out:
# '0.2.1'

# %%
import pandas as pd
house_data = pd.read_csv('../data/kc_house_data.csv')
crime_data = pd.read_csv('../data/King_County_Sheriff_s_Office.csv')
# Out:
# /Users/hunting/miniconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
house_data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
import folium
map_kingcounty = folium.Map(location=[47.53973, -122.22963])
map_kingcounty
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
lats = []
lons = []
house_IDs = []

for i in range(0, 100):
    lats.append(house_data.lat[i])
    lons.append(house_data.long[i])
    house_IDs.append(house_data.id[i])

house_GPSs = list(zip(lats, lons))
popups = ['house_id: '+'{}'.format(info) for info in house_IDs]

# %%
from folium.plugins import MarkerCluster
import numpy as np
house_map = folium.Map(location=[np.mean(lats), np.mean(lons)],   
                  tiles='Cartodb Positron', width='80%')
house_map.add_child(MarkerCluster(locations=house_GPSs, popups=popups))
house_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
