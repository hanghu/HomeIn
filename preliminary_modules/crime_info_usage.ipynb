# %%
import pandas as pd
import numpy as np
from crime_info import crime_count
house_data = pd.read_csv('../data/kc_house_data.csv')
crime_data = pd.read_csv('../data/cleaned_crime_data.csv')
crime_type = list(crime_data['incident_type_primary'])
crime_type_list = list(crime_data['incident_type_primary'].unique())
crime_lats = list(crime_data.latitude)
crime_lons = list(crime_data.longitude)
crime_gps = list(zip(crime_lats,crime_lons))

# %%
import matplotlib
# %matplotlib inline
house_gps = (house_data.lat[0], house_data.long[0])
(count_numb, grouped_crime) = crime_count(house_gps, crime_gps, crime_type)

# %%
grouped_crime
# Out:
# Counter({'Assault': 32,
#          'Breaking & Entering': 131,
#          'Drugs': 11,
#          'Property Crime': 85,
#          'Robbery': 6,
#          'Theft': 39,
#          'Theft from Vehicle': 54,
#          'Theft of Vehicle': 50})

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(12, 6))
c_plot = ax.barh(range(len(grouped_crime)), grouped_crime.values(), align='center')
plt.yticks(range(len(grouped_crime)), grouped_crime.keys())
# Out:
# ([<matplotlib.axis.YTick at 0x110afb128>,
#   <matplotlib.axis.YTick at 0x110afb6a0>,
#   <matplotlib.axis.YTick at 0x1106d1748>,
#   <matplotlib.axis.YTick at 0x1105e2128>,
#   <matplotlib.axis.YTick at 0x1105ad748>,
#   <matplotlib.axis.YTick at 0x1105ad3c8>,
#   <matplotlib.axis.YTick at 0x1105b37b8>,
#   <matplotlib.axis.YTick at 0x11051d898>],
#  <a list of 8 Text yticklabel objects>)

# %%
list(grouped_crime.values())
# Out:
# [50, 54, 32, 6, 39, 85, 11, 131]

# %%
len(grouped_crime.values())
# Out:
# 8
